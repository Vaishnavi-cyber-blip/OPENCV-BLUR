# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi-cyber-blip/OPENCV-BLUR/blob/main/ME_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# Read the image.
img = cv2.imread('taj.jpg')

# Apply bilateral filter with d = 15,
# sigmaColor = sigmaSpace = 75.
bilateral = cv2.bilateralFilter(img, 15, 75, 75)

# Save the output.
cv2.imwrite('taj_bilateral.jpg', bilateral)
from google.colab.patches import cv2_imshow
cv2_imshow(bilateral)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F103E0EB750>

# %%
MEDIAN = cv2.medianBlur(img, 5)
cv2_imshow(MEDIAN)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F102E9F1410>
